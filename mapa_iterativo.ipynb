# %%
import pandas as pd
import folium
from geopy.geocoders import Nominatim
from folium.plugins import MarkerCluster
import time

# %%
def tratar_dados(row: pd.DataFrame):
    logadouro = row['Logadouro'].split(',')
    cep = row['CEP'].replace('.', '')

    return logadouro, cep

# %%
dados_empresas = pd.read_excel("./dados/dados_empresas.xlsx")

# Inicializar o geocodificador
geolocator = Nominatim(user_agent="mapa_empresas")

# Criar uma nova coluna para armazenar coordenadas
dados_empresas['Coordenadas'] = None

# Função para obter coordenadas
def obter_coordenadas(endereco):
    try:
        localizacao = geolocator.geocode(endereco)
        if localizacao:
            return (localizacao.latitude, localizacao.longitude)
    except:
        return None

# Iterar pelos endereços e buscar as coordenadas
for i, row in dados_empresas.iterrows():
    logadouro, cep = tratar_dados(row)

    if len(logadouro) > 1:
        endereco = f'{logadouro[0]}, {logadouro[1]}, {cep}'
    else:
        endereco = f'{logadouro[0]}, {cep}'


    coordenadas = obter_coordenadas(endereco)
    dados_empresas.at[i, 'Coordenadas'] = coordenadas
    time.sleep(1)

# Filtrar empresas com coordenadas válidas
dados_empresas_com_coords = dados_empresas.dropna(subset=['Coordenadas'])

# Criar o mapa centralizado em Belém
mapa = folium.Map(location=[-1.455, -48.502], zoom_start=12)

# Adicionar um agrupador de marcadores
marker_cluster = MarkerCluster().add_to(mapa)

# Adicionar os marcadores ao mapa
for i, row in dados_empresas_com_coords.iterrows():
    tooltip_info = f"""
    <b>Nome:</b> {row['Nome']}<br>
    <b>Razão Social:</b> {row['Razao Social']}<br>
    <b>CNPJ:</b> {row['CNPJ']}<br>
    <b>Situação:</b> {row['Situacao']}<br>
    <b>Endereço:</b> {row['Logadouro']}<br>
    <b>Bairro:</b> {row['Bairro']}<br>
    """
    folium.Marker(
        location=row['Coordenadas'],
        popup=folium.Popup(tooltip_info, max_width=300),
        tooltip=row['Nome']
    ).add_to(marker_cluster)

# Salvar o mapa em HTML
mapa.save("./mapas/mapa_empresas.html")
print("Mapa salvo como mapa_empresas.html")
# Out:
# Mapa salvo como mapa_empresas.html

# %%
dados_empresas
# Out:
#                                     Nome  \
# 0                       COCO BAMBU BELEM
# 1                      FAMIGLIA D'ITALIA
# 2                        EMPORIO GOURMET
# 3                          MANJAR BUFFET
# 4                         Não Disponível
# 5                              S  K CAFE
# 6                         Não Disponível
# 7                             MCDONALD'S
# 8                         Não Disponível
# 9                   PH COMPANY ALIMENTOS
# 10                     TIO ARMENIO GRILL
# 11                                 BOS S
# 12                            ZIO CUCINA
# 13                                INSANO
# 14                            ZIO CUCINA
# 15             SAL E BRASA GRILL EXPRESS
# 16                  BOI NOVO CHURASCARIA
# 17        RESTAURANTE CARNE DE SOL PICUI
# 18                        Não Disponível
# 19                    PORPINO WANDENKOLK
# 20                 SUSHI CONVENIENCIA RM
# 21                    DIAMOND LOUNGE BAR
# 22  CASA BAUDUCCO  PARQUE SHOPPING BELEM
# 23                      RESTO MONTENEGRO
# 24                      PANORAMICA RESTO
# 25    CHURRASCARIA E PIZZARIA BOI D'OURO
# 26                        Não Disponível
# 27        BLEM PADARIA PORTUGUESA  BELEM
# 28                RESTAURANTE VER O ACAI
# 29                       PORTO VER O RIO
# 30                    BOTECO SANTA MATTA
# 31          BALACOOLBAR BAR  RESTAURANTE
# 32                   CAFE SANTO  MARUJOS
# 33                GRUPO R S LYNO HOLDING
# 34                      PROSPERA SERVICE
# 35                             RUSTY PUB
# 36                        BALL DIVERSOES
# 37               CHURRASCARIA BOI D'OURO
# 38                           BBQ PREMIUM
# 39                        Não Disponível
# 40                      PONTAL DAS ILHAS
# 41                            AMAR BELEM
# 42                       CASAMIA EVENTOS
# 43                        Não Disponível
# 44         CHURRASCARIA BOI D'OURO PRIME
# 45                        PALICONE BELEM
# 46                         LGOM SERVICOS
# 47                  PEIXARIA DOM FILHOTE
# 48    CHURRASCARIA E PIZZARIA BOI D'OURO
# 49                          GELATO BELEM
#
#                                          Razao Social                CNPJ  \
# 0                 CB BELEM COMERCIO DE ALIMENTOS LTDA  46.472.087/0001-09
# 1       FAMIGLIA DI ITALIA COMERCIO DE ALIMENTOS LTDA  30.746.245/0001-23
# 2                           MWS EVENTOS E BUFFET LTDA  07.370.589/0001-69
# 3                          ACG BAR E RESTAURANTE LTDA  29.993.405/0001-50
# 4            W S R MARTINS SERVICOS DE ALIMENTOS LTDA  01.092.367/0001-45
# 5                                S  K LANCHONETE LTDA  17.214.358/0001-10
# 6                      KCR COMERCIO DE ALIMENTOS LTDA  02.637.777/0001-97
# 7                      KRC COMERCIO DE ALIMENTOS LTDA  28.926.349/0001-78
# 8                    MWS EVENTOS E BUFFET EIRELLI SCP  38.826.444/0001-53
# 9                      RBL COMERCIO DE ALIMENTOS LTDA  18.555.248/0001-84
# 10                   EVORA COMERCIO DE ALIMENTOS LTDA  53.739.494/0001-97
# 11                       BOSS INDUSTRIA E COMERCIO SA  05.083.795/0001-62
# 12                         TORTORETO RESTAURANTE LTDA  44.122.709/0001-35
# 13                         RUPF  VITAL PRODUCOES LTDA  05.135.562/0001-66
# 14                 CAPRI RESTAURANTE E ALIMENTOS LTDA  35.486.391/0001-80
# 15  VASCONCELOS E SILVA COMERCIO DE ALIMENTOS E BE...  36.237.312/0001-60
# 16                      C DILAN ALENCAR DA SILVA LTDA  21.371.565/0001-55
# 17                             FABRIZIO M SANTOS LTDA  00.559.243/0001-64
# 18               J P C DOS S COMERCIO E SERVICOS LTDA  41.326.700/0001-58
# 19                           PORPINO ALIMENTACAO LTDA  22.365.768/0001-00
# 20                         SUSHI CONVENIENCIA RM LTDA  48.010.551/0001-62
# 21                            DIAMOND LOUNGE BAR LTDA  48.625.596/0001-41
# 22                NESBELLO COMERCIO DE ALIMENTOS LTDA  56.423.032/0001-54
# 23                          MONTENEGRO ALIMENTOS LTDA  47.480.052/0001-76
# 24                             S A VALE DA SILVA LTDA  45.649.495/0001-12
# 25                                  SILVA  GUGEL LTDA  15.393.207/0001-40
# 26                             S  L RESTAURANTES LTDA  04.932.361/0001-27
# 27                                       MP BLEM LTDA  49.930.853/0001-11
# 28         ANDRADE FACANHA COMERCIO DE ALIMENTOS LTDA  02.515.642/0001-59
# 29              NORTE FOOD COMERCIO DE ALIMENTOS LTDA  05.476.623/0001-59
# 30                                 A V RODRIGUES LTDA  50.274.408/0001-20
# 31                  BALACOOLBAR BAR  RESTAURANTE LTDA  39.718.557/0001-06
# 32                                   G R CASTRO ALVES  01.910.679/0001-19
# 33                                SILVA E SOLYNO LTDA  28.056.249/0001-38
# 34                              PROSPERA SERVICE LTDA  15.011.217/0001-74
# 35                                    PAGNO  CIA LTDA  22.357.869/0001-20
# 36               BALL DIVERSOES  ENTRETENIMENTOS LTDA  26.625.531/0001-63
# 37                                VACARIN  GUGEL LTDA  16.685.636/0001-54
# 38                           MUIRAQUITA BUSINESS LTDA  37.843.427/0001-61
# 39                SANTUNES COMERCIO DE ALIMENTOS LTDA  51.668.229/0001-30
# 40                                PONTAL DA ILHA LTDA  53.209.819/0001-20
# 41                                 HRB DE ARAUJO LTDA  55.802.402/0001-00
# 42                               CASAMIA EVENTOS LTDA  48.708.807/0001-00
# 43         PROAM PRODUTOS E SERVICOS DA AMAZONIA LTDA  04.373.034/0001-82
# 44                 CHURRASCARIA BOI D'OURO PRIME LTDA  12.010.851/0001-02
# 45                                PALICONE BELEM LTDA  48.767.935/0001-24
# 46                                 LGOM SERVICOS LTDA  33.825.804/0001-89
# 47                       RESTAURANTE DOM FILHOTE LTDA  33.597.155/0001-06
# 48                                    GUGEL  CIA LTDA  09.320.832/0001-60
# 49                   U L A COMERCIO DE ALIMENTOS LTDA  53.929.126/0001-01
#
#                   Situacao                                          Logadouro  \
# 0   ATIVA desde 20/05/2022                          Rodovia dos Trabalhadores
# 1   ATIVA desde 20/06/2018  Avenida Visconde de Souza Franco, 776, Sala 44...
# 2                    ATIVA                               Travessa Timbo, 2212
# 3   ATIVA desde 21/03/2018                    Avenida Gentil Bittencourt, 344
# 4   ATIVA desde 18/03/2022                Avenida Generalissimo Deodoro, 1513
# 5   ATIVA desde 26/11/2012                    Travessa Humaita, 1598, Andar 3
# 6   ATIVA desde 14/08/2004  Travessa Padre Eutiquio, 1078, Lojas 411/12/13...
# 7   ATIVA desde 24/10/2017  Rodovia Augusto Montenegro, 4300, Loja 2011 e ...
# 8   ATIVA desde 04/11/2019                               Travessa Timbo, 2212
# 9   ATIVA desde 10/05/2022                       Avenida Duque de Caxias, 708
# 10  ATIVA desde 31/01/2024                                     Rodovia Br-316
# 11  ATIVA desde 03/11/2005              Avenida Governador Jose Malcher, 2377
# 12  ATIVA desde 04/11/2021                         Boulevard Castilhos Franca
# 13  ATIVA desde 03/08/2022                            Rua Sao Boaventura, 268
# 14  ATIVA desde 12/11/2019                          Rodovia dos Trabalhadores
# 15  ATIVA desde 04/02/2020        Rodovia Augusto Montenegro, 4300, Loja 2006
# 16  ATIVA desde 07/11/2014           Avenida Governador Magalhaes Barata, 774
# 17  ATIVA desde 03/11/2005                             Travessa Mauriti, 2170
# 18  ATIVA desde 23/06/2024                          Travessa Bom Jardim, 2124
# 19  ATIVA desde 30/04/2015                  Rua Conego Jeronimo Pimentel, 242
# 20  ATIVA desde 20/09/2022                      Avenida Romulo Maiorana, 1444
# 21  ATIVA desde 16/11/2022              Avenida Visconde de Souza Franco, 415
# 22  ATIVA desde 09/08/2024  Rodovia Augusto Montenegro, 4300, Andar Terreo...
# 23  ATIVA desde 09/08/2022             Rodovia Augusto Montenegro, 981, Km 07
# 24  ATIVA desde 14/03/2022                      Estrada do Carananduba, 655 A
# 25  ATIVA desde 27/10/2011  Avenida Duque de Caxias, 427, Esq. Travessa Cu...
# 26  ATIVA desde 13/09/2022                                     Rodovia Br-316
# 27  ATIVA desde 14/03/2023    Avenida Visconde de Souza Franco, 776, Loja 214
# 28  ATIVA desde 03/11/2005                          Travessa Dom Pedro I, 599
# 29  ATIVA desde 03/11/2005        Avenida Pedro Alvares Cabral, 1101, Setor a
# 30  ATIVA desde 11/04/2023                         Rua Rodolfo Chermont, 1607
# 31  ATIVA desde 09/11/2020                           Praça Kennedy, 2, Sala 3
# 32  ATIVA desde 03/11/2005                    Boulevard Castilhos Franca, 504
# 33  ATIVA desde 17/06/2022                 Travessa Almirante Wandenkolk, 362
# 34  ATIVA desde 07/02/2012                  Avenida Conselheiro Furtado, 3926
# 35  ATIVA desde 30/04/2015              Travessa Vileta, 2509, Andar: Terreo;
# 36  ATIVA desde 29/11/2016                          Rodovia dos Trabalhadores
# 37  ATIVA desde 03/03/2022                   Rodovia Augusto Montenegro, 1802
# 38  ATIVA desde 24/07/2020              Avenida Romulo Maiorana, 700, Sala 01
# 39  ATIVA desde 03/08/2023  Avenida Visconde de Souza Franco, 776, Shoppin...
# 40  ATIVA desde 15/12/2023                     Rodovia Augusto Montenegro, 28
# 41  ATIVA desde 04/07/2024                Travessa Almirante Wandenkolk, 1225
# 42  ATIVA desde 23/11/2022            Travessa Quintino Bocaiuva, 1678, Altos
# 43  ATIVA desde 03/11/2005                         Passagem Sao Sebastiao, 58
# 44  ATIVA desde 28/05/2010                         Avenida Joao Paulo Ii, 395
# 45  ATIVA desde 30/11/2022                      Travessa Padre Eutiquio, 2188
# 46  ATIVA desde 04/06/2019  Travessa Quatorze de Marco, 393, Galpaoprox. A...
# 47  ATIVA desde 13/05/2019                         Avenida Jose Bonifacio, 48
# 48  ATIVA desde 04/01/2008                   Avenida Almirante Tamandare, 912
# 49  ATIVA desde 15/02/2024  Avenida Visconde de Souza Franco, 776, Shoppin...
#
#                      Bairro Municipio/UF         CEP  \
# 0              Parque Verde    Belem, PA  66.635-894
# 1                    Reduto    Belem, PA  66.053-000
# 2                     Marco    Belem, PA  66.095-531
# 3            Batista Campos    Belem, PA  66.035-340
# 4                    Nazare    Belem, PA  66.035-090
# 5                  Pedreira    Belem, PA  66.085-148
# 6            Batista Campos    Belem, PA  66.023-710
# 7              Parque Verde    Belem, PA  66.635-110
# 8                     Marco    Belem, PA  66.095-531
# 9                     Marco    Belem, PA  66.093-026
# 10              Castanheira    Belem, PA  66.645-000
# 11                   Nazare    Belem, PA  66.060-230
# 12                  Campina    Belem, PA  66.010-020
# 13             Cidade Velha    Belem, PA  66.020-550
# 14             Parque Verde    Belem, PA  66.635-894
# 15             Parque Verde    Belem, PA  66.635-110
# 16                 Sao Bras    Belem, PA  66.060-281
# 17                 Pedreira    Belem, PA  66.087-680
# 18                  Jurunas    Belem, PA  66.025-180
# 19                 Umarizal    Belem, PA  66.055-000
# 20                    Marco    Belem, PA  66.093-674
# 21                 Umarizal    Belem, PA  66.055-005
# 22             Parque Verde    Belem, PA  66.635-110
# 23             Parque Verde    Belem, PA  66.635-110
# 24  Carananduba (mosqueiro)    Belem, PA  66.923-040
# 25                    Marco    Belem, PA  66.093-026
# 26              Castanheira    Belem, PA  66.645-000
# 27                   Reduto    Belem, PA  66.053-000
# 28                 Umarizal    Belem, PA  66.050-100
# 29                 Umarizal    Belem, PA  66.050-400
# 30                Marambaia    Belem, PA  66.615-170
# 31                  Campina    Belem, PA  66.010-040
# 32                  Campina    Belem, PA  66.010-020
# 33                 Umarizal    Belem, PA  66.055-045
# 34                    Guama    Belem, PA  66.073-160
# 35                    Marco    Belem, PA  66.093-345
# 36             Parque Verde    Belem, PA  66.635-894
# 37               Mangueirao    Belem, PA  66.640-000
# 38                    Marco    Belem, PA  66.093-672
# 39                   Reduto    Belem, PA  66.053-000
# 40                   Tenone    Belem, PA  66.820-000
# 41                 Umarizal    Belem, PA  66.055-045
# 42                   Nazare    Belem, PA  66.035-190
# 43                    Marco    Belem, PA  66.095-590
# 44                    Marco    Belem, PA  66.095-491
# 45           Batista Campos    Belem, PA  66.033-726
# 46                 Umarizal    Belem, PA  66.055-490
# 47                   Fatima    Belem, PA  66.090-363
# 48             Cidade Velha    Belem, PA  66.020-000
# 49                   Reduto    Belem, PA  66.053-000
#
#                                    Coordenadas
# 0    (-1.3905464158067857, -48.47294572197383)
# 1           (-1.44632925, -48.489719744011424)
# 2    (-1.4362571013904253, -48.46535418025257)
# 3                    (-1.4563164, -48.4891835)
# 4    (-1.4542848290697674, -48.48263446395349)
# 5    (-1.4374474112587547, -48.46895015688325)
# 6             (-1.458131, -48.494854802692934)
# 7    (-1.3656050914186721, -48.44820701506224)
# 8    (-1.4362571013904253, -48.46535418025257)
# 9                     (-1.436568, -48.4659974)
# 10  (-1.3918980614816898, -48.417318168034654)
# 11   (-1.448240333307018, -48.472426412052286)
# 12      (-1.4489001248157, -48.49977161233916)
# 13   (-1.4618891554347826, -48.50525017608696)
# 14   (-1.3905464158067857, -48.47294572197383)
# 15   (-1.3656050914186721, -48.44820701506224)
# 16   (-1.4518648432316743, -48.47359077996469)
# 17   (-1.4328537434247124, -48.46503429169043)
# 18   (-1.4740591850662044, -48.48830586062587)
# 19   (-1.4427185786847463, -48.48815072555877)
# 20   (-1.4351138140545932, -48.46124902894093)
# 21    (-1.4423534965577038, -48.4911274177954)
# 22   (-1.3656050914186721, -48.44820701506224)
# 23   (-1.3656050914186721, -48.44820701506224)
# 24                                        None
# 25                   (-1.4405297, -48.4692228)
# 26  (-1.3918980614816898, -48.417318168034654)
# 27          (-1.44632925, -48.489719744011424)
# 28           (-1.4371763, -48.488230187368416)
# 29  (-1.4345321827383122, -48.491299556970816)
# 30                 (-1.45290675, -48.48096515)
# 31                                        None
# 32                   (-1.4498903, -48.5004611)
# 33                    (-1.441312, -48.4900629)
# 34  (-1.4557447844158407, -48.462525311088704)
# 35  (-1.4392242456177626, -48.463195513297606)
# 36   (-1.3905464158067857, -48.47294572197383)
# 37  (-1.3847718192585718, -48.437194326701736)
# 38                   (-1.4413315, -48.4653389)
# 39          (-1.44632925, -48.489719744011424)
# 40        (-1.3019052536, -48.477318683200004)
# 41                   (-1.4472465, -48.4855494)
# 42   (-1.4540109639367262, -48.48613148281963)
# 43                                        None
# 44   (-1.4446394259257618, -48.46045400546621)
# 45                   (-1.4639197, -48.4864819)
# 46             (-1.4347498625, -48.4804931625)
# 47        (-1.4470554999999998, -48.469332725)
# 48   (-1.4579824352176463, -48.49742338925528)
# 49          (-1.44632925, -48.489719744011424)
